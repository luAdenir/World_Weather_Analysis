# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from scipy import stats
# %matplotlib inline

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1a91928602efacb3650a4c99600d3e2

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 759

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = city_url=url+ "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
    
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | waitati
# Processing Record 4 of Set 1 | bluff
# Processing Record 5 of Set 1 | qaanaaq
# Processing Record 6 of Set 1 | lompoc
# Processing Record 7 of Set 1 | geraldton
# Processing Record 8 of Set 1 | alice springs
# Processing Record 9 of Set 1 | barrow
# Processing Record 10 of Set 1 | kapaa
# Processing Record 11 of Set 1 | pangody
# Processing Record 12 of Set 1 | henties bay
# Processing Record 13 of Set 1 | bitung
# Processing Record 14 of Set 1 | porto novo
# Processing Record 15 of Set 1 | fortuna
# Processing Record 16 of Set 1 | saint george
# Processing Record 17 of Set 1 | hithadhoo
# Processing Record 18 of Set 1 | tidore
# City not found. Skipping...
# Processing Record 19 of Set 1 | oskarshamn
# Processing Record 20 of Set 1 | esperance
# Processing Record 21 of Set 1 | voznesenye
# Processing Record 22 of Set 1 | tasiilaq
# Processing Record 23 of Set 1 | tomatlan
# Processing Record 24 of Set 1 | grand gaube
# Processing Record 25 of Set 1 | lebu
# Processing Record 26 of Set 1 | inhambane
# Processing Record 27 of Set 1 | svetlogorsk
# Processing Record 28 of Set 1 | ulety
# Processing Record 29 of Set 1 | kalashnikovo
# Processing Record 30 of Set 1 | grindavik
# Processing Record 31 of Set 1 | tuatapere
# Processing Record 32 of Set 1 | along
# Processing Record 33 of Set 1 | vila franca do campo
# Processing Record 34 of Set 1 | puerto ayora
# Processing Record 35 of Set 1 | namie
# Processing Record 36 of Set 1 | bathurst
# Processing Record 37 of Set 1 | rikitea
# Processing Record 38 of Set 1 | mahebourg
# Processing Record 39 of Set 1 | paita
# Processing Record 40 of Set 1 | east london
# Processing Record 41 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 42 of Set 1 | puyo
# Processing Record 43 of Set 1 | dikson
# Processing Record 44 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 1 | ponta do sol
# Processing Record 46 of Set 1 | upernavik
# Processing Record 47 of Set 1 | ushuaia
# Processing Record 48 of Set 1 | leningradskiy
# Processing Record 49 of Set 1 | butaritari
# Processing Record 50 of Set 1 | cape town
# Processing Record 1 of Set 2 | mataura
# Processing Record 2 of Set 2 | colomi
# Processing Record 3 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 2 | hilo
# Processing Record 5 of Set 2 | port alfred
# Processing Record 6 of Set 2 | aykhal
# Processing Record 7 of Set 2 | yorosso
# Processing Record 8 of Set 2 | georgetown
# Processing Record 9 of Set 2 | bredasdorp
# Processing Record 10 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 11 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 2 | ajdabiya
# Processing Record 13 of Set 2 | severo-kurilsk
# Processing Record 14 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 2 | magaria
# Processing Record 16 of Set 2 | terney
# Processing Record 17 of Set 2 | kizema
# Processing Record 18 of Set 2 | victoria
# Processing Record 19 of Set 2 | togur
# Processing Record 20 of Set 2 | busselton
# Processing Record 21 of Set 2 | whitehorse
# Processing Record 22 of Set 2 | new norfolk
# Processing Record 23 of Set 2 | aksarka
# Processing Record 24 of Set 2 | lagoa
# Processing Record 25 of Set 2 | clyde river
# Processing Record 26 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 2 | anadyr
# Processing Record 28 of Set 2 | uchiza
# Processing Record 29 of Set 2 | pirapora
# Processing Record 30 of Set 2 | benin
# Processing Record 31 of Set 2 | latur
# Processing Record 32 of Set 2 | narsaq
# Processing Record 33 of Set 2 | pevek
# Processing Record 34 of Set 2 | hermanus
# Processing Record 35 of Set 2 | souillac
# Processing Record 36 of Set 2 | mehamn
# Processing Record 37 of Set 2 | akhnur
# Processing Record 38 of Set 2 | adrar
# Processing Record 39 of Set 2 | sabzevar
# Processing Record 40 of Set 2 | airai
# Processing Record 41 of Set 2 | lasa
# Processing Record 42 of Set 2 | katsuura
# Processing Record 43 of Set 2 | cayenne
# Processing Record 44 of Set 2 | nishihara
# Processing Record 45 of Set 2 | gimbi
# Processing Record 46 of Set 2 | iquitos
# Processing Record 47 of Set 2 | waipawa
# Processing Record 48 of Set 2 | berlevag
# Processing Record 49 of Set 2 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 50 of Set 2 | lorengau
# Processing Record 1 of Set 3 | colares
# Processing Record 2 of Set 3 | ust-koksa
# Processing Record 3 of Set 3 | komsomolskiy
# Processing Record 4 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 5 of Set 3 | kaoma
# Processing Record 6 of Set 3 | torva
# Processing Record 7 of Set 3 | port elizabeth
# Processing Record 8 of Set 3 | arraial do cabo
# Processing Record 9 of Set 3 | teshie
# Processing Record 10 of Set 3 | bud
# Processing Record 11 of Set 3 | kautokeino
# Processing Record 12 of Set 3 | saskylakh
# Processing Record 13 of Set 3 | sorland
# Processing Record 14 of Set 3 | russell
# Processing Record 15 of Set 3 | balkhash
# Processing Record 16 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 3 | ancud
# Processing Record 18 of Set 3 | touros
# Processing Record 19 of Set 3 | namibe
# Processing Record 20 of Set 3 | husavik
# Processing Record 21 of Set 3 | norman wells
# Processing Record 22 of Set 3 | bethel
# Processing Record 23 of Set 3 | saint marys
# Processing Record 24 of Set 3 | yellowknife
# Processing Record 25 of Set 3 | hobart
# Processing Record 26 of Set 3 | avarua
# Processing Record 27 of Set 3 | hasaki
# Processing Record 28 of Set 3 | chokurdakh
# Processing Record 29 of Set 3 | san cristobal
# Processing Record 30 of Set 3 | taoudenni
# Processing Record 31 of Set 3 | acapulco
# Processing Record 32 of Set 3 | harper
# Processing Record 33 of Set 3 | thompson
# Processing Record 34 of Set 3 | buala
# Processing Record 35 of Set 3 | kazerun
# Processing Record 36 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 37 of Set 3 | okhotsk
# Processing Record 38 of Set 3 | carnarvon
# Processing Record 39 of Set 3 | aklavik
# Processing Record 40 of Set 3 | sassandra
# Processing Record 41 of Set 3 | ixtapa
# Processing Record 42 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 43 of Set 3 | dingle
# Processing Record 44 of Set 3 | sitka
# Processing Record 45 of Set 3 | andros town
# Processing Record 46 of Set 3 | severnyy-kospashskiy
# Processing Record 47 of Set 3 | yinchuan
# Processing Record 48 of Set 3 | tabou
# Processing Record 49 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 50 of Set 3 | amapa
# Processing Record 1 of Set 4 | los llanos de aridane
# Processing Record 2 of Set 4 | cooma
# Processing Record 3 of Set 4 | pangnirtung
# Processing Record 4 of Set 4 | saint-philippe
# Processing Record 5 of Set 4 | vila velha
# Processing Record 6 of Set 4 | vaini
# Processing Record 7 of Set 4 | nikolskoye
# Processing Record 8 of Set 4 | yugorsk
# Processing Record 9 of Set 4 | fevralsk
# City not found. Skipping...
# Processing Record 10 of Set 4 | iberia
# Processing Record 11 of Set 4 | zhigansk
# Processing Record 12 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 13 of Set 4 | poya
# Processing Record 14 of Set 4 | koumac
# Processing Record 15 of Set 4 | julio de castilhos
# Processing Record 16 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 4 | broome
# Processing Record 18 of Set 4 | provideniya
# Processing Record 19 of Set 4 | asayita
# City not found. Skipping...
# Processing Record 20 of Set 4 | pierre
# Processing Record 21 of Set 4 | tres palos
# Processing Record 22 of Set 4 | kodiak
# Processing Record 23 of Set 4 | lavrentiya
# Processing Record 24 of Set 4 | rafraf
# Processing Record 25 of Set 4 | san jose
# Processing Record 26 of Set 4 | gravdal
# Processing Record 27 of Set 4 | alofi
# Processing Record 28 of Set 4 | bengkulu
# Processing Record 29 of Set 4 | ati
# Processing Record 30 of Set 4 | zhukovo
# Processing Record 31 of Set 4 | nouadhibou
# Processing Record 32 of Set 4 | ribeira grande
# Processing Record 33 of Set 4 | zaykovo
# Processing Record 34 of Set 4 | chuy
# Processing Record 35 of Set 4 | nagato
# Processing Record 36 of Set 4 | abeche
# Processing Record 37 of Set 4 | bataipora
# Processing Record 38 of Set 4 | kihei
# Processing Record 39 of Set 4 | orel-izumrud
# Processing Record 40 of Set 4 | iqaluit
# Processing Record 41 of Set 4 | vardo
# Processing Record 42 of Set 4 | kerteh
# City not found. Skipping...
# Processing Record 43 of Set 4 | polis
# Processing Record 44 of Set 4 | jiuquan
# Processing Record 45 of Set 4 | izhma
# Processing Record 46 of Set 4 | opuwo
# Processing Record 47 of Set 4 | castro
# Processing Record 48 of Set 4 | ban nahin
# Processing Record 49 of Set 4 | atar
# Processing Record 50 of Set 4 | progreso
# Processing Record 1 of Set 5 | aasiaat
# Processing Record 2 of Set 5 | havelock
# Processing Record 3 of Set 5 | san patricio
# Processing Record 4 of Set 5 | tiksi
# Processing Record 5 of Set 5 | guozhen
# Processing Record 6 of Set 5 | iwaki
# Processing Record 7 of Set 5 | caravelas
# Processing Record 8 of Set 5 | itahari
# City not found. Skipping...
# Processing Record 9 of Set 5 | berdyuzhye
# City not found. Skipping...
# Processing Record 10 of Set 5 | olafsvik
# Processing Record 11 of Set 5 | guerrero negro
# Processing Record 12 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 5 | guamuchil
# Processing Record 14 of Set 5 | teahupoo
# Processing Record 15 of Set 5 | formosa do rio preto
# Processing Record 16 of Set 5 | kirakira
# Processing Record 17 of Set 5 | morehead
# Processing Record 18 of Set 5 | darhan
# Processing Record 19 of Set 5 | nurota
# Processing Record 20 of Set 5 | asyut
# Processing Record 21 of Set 5 | fairbanks
# Processing Record 22 of Set 5 | ikongo
# Processing Record 23 of Set 5 | arlit
# Processing Record 24 of Set 5 | yenagoa
# Processing Record 25 of Set 5 | alto araguaia
# Processing Record 26 of Set 5 | saint anthony
# Processing Record 27 of Set 5 | marquette
# Processing Record 28 of Set 5 | ituni
# City not found. Skipping...
# Processing Record 29 of Set 5 | passos
# Processing Record 30 of Set 5 | sisimiut
# Processing Record 31 of Set 5 | mafinga
# Processing Record 32 of Set 5 | zapolyarnyy
# Processing Record 33 of Set 5 | magnor
# Processing Record 34 of Set 5 | mar del plata
# Processing Record 35 of Set 5 | ilulissat
# Processing Record 36 of Set 5 | sozimskiy
# Processing Record 37 of Set 5 | port macquarie
# Processing Record 38 of Set 5 | palomares
# Processing Record 39 of Set 5 | andapa
# Processing Record 40 of Set 5 | livani
# Processing Record 41 of Set 5 | kichera
# Processing Record 42 of Set 5 | champerico
# Processing Record 43 of Set 5 | phalombe
# Processing Record 44 of Set 5 | purranque
# Processing Record 45 of Set 5 | luderitz
# Processing Record 46 of Set 5 | hovd
# Processing Record 47 of Set 5 | imbituba
# Processing Record 48 of Set 5 | koslan
# Processing Record 49 of Set 5 | jamestown
# Processing Record 50 of Set 5 | xunchang
# Processing Record 1 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 6 | kaitangata
# Processing Record 3 of Set 6 | batagay-alyta
# Processing Record 4 of Set 6 | arman
# Processing Record 5 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 6 of Set 6 | shubarshi
# Processing Record 7 of Set 6 | collie
# Processing Record 8 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 9 of Set 6 | biak
# Processing Record 10 of Set 6 | tarauaca
# Processing Record 11 of Set 6 | khandyga
# Processing Record 12 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 13 of Set 6 | agucadoura
# Processing Record 14 of Set 6 | alabaster
# Processing Record 15 of Set 6 | grammichele
# Processing Record 16 of Set 6 | vicuna
# Processing Record 17 of Set 6 | aden
# Processing Record 18 of Set 6 | barauli
# Processing Record 19 of Set 6 | raton
# Processing Record 20 of Set 6 | saint-joseph
# Processing Record 21 of Set 6 | noumea
# Processing Record 22 of Set 6 | listvyanka
# Processing Record 23 of Set 6 | shaki
# Processing Record 24 of Set 6 | penalva
# Processing Record 25 of Set 6 | vostok
# Processing Record 26 of Set 6 | dalen
# Processing Record 27 of Set 6 | hanmer springs
# Processing Record 28 of Set 6 | kasli
# Processing Record 29 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 30 of Set 6 | trairi
# Processing Record 31 of Set 6 | atuona
# Processing Record 32 of Set 6 | karakol
# Processing Record 33 of Set 6 | pasighat
# Processing Record 34 of Set 6 | berbera
# Processing Record 35 of Set 6 | padang
# Processing Record 36 of Set 6 | paamiut
# Processing Record 37 of Set 6 | cidreira
# Processing Record 38 of Set 6 | port lincoln
# Processing Record 39 of Set 6 | warrington
# Processing Record 40 of Set 6 | sambava
# Processing Record 41 of Set 6 | tambopata
# Processing Record 42 of Set 6 | vangaindrano
# Processing Record 43 of Set 6 | thinadhoo
# Processing Record 44 of Set 6 | saint-augustin
# Processing Record 45 of Set 6 | umm lajj
# Processing Record 46 of Set 6 | brae
# Processing Record 47 of Set 6 | khormuj
# City not found. Skipping...
# Processing Record 48 of Set 6 | tiznit
# Processing Record 49 of Set 6 | cabo san lucas
# Processing Record 50 of Set 6 | sao jose da coroa grande
# Processing Record 1 of Set 7 | severo-yeniseyskiy
# Processing Record 2 of Set 7 | ilebo
# Processing Record 3 of Set 7 | adre
# Processing Record 4 of Set 7 | khatanga
# Processing Record 5 of Set 7 | mercedes
# Processing Record 6 of Set 7 | don sak
# Processing Record 7 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 8 of Set 7 | buraydah
# Processing Record 9 of Set 7 | emilio carranza
# Processing Record 10 of Set 7 | rockhampton
# Processing Record 11 of Set 7 | kahului
# Processing Record 12 of Set 7 | daxian
# City not found. Skipping...
# Processing Record 13 of Set 7 | viedma
# Processing Record 14 of Set 7 | karratha
# Processing Record 15 of Set 7 | belaya gora
# Processing Record 16 of Set 7 | sola
# Processing Record 17 of Set 7 | torbay
# Processing Record 18 of Set 7 | buqayq
# City not found. Skipping...
# Processing Record 19 of Set 7 | atambua
# Processing Record 20 of Set 7 | sao felix do xingu
# Processing Record 21 of Set 7 | tuktoyaktuk
# Processing Record 22 of Set 7 | klaksvik
# Processing Record 23 of Set 7 | xining
# Processing Record 24 of Set 7 | gat
# Processing Record 25 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 26 of Set 7 | paka
# Processing Record 27 of Set 7 | luanda
# Processing Record 28 of Set 7 | chapais
# Processing Record 29 of Set 7 | gushikawa
# Processing Record 30 of Set 7 | boende
# Processing Record 31 of Set 7 | nome
# Processing Record 32 of Set 7 | den helder
# Processing Record 33 of Set 7 | ugoofaaru
# Processing Record 34 of Set 7 | elmina
# Processing Record 35 of Set 7 | half moon bay
# Processing Record 36 of Set 7 | sioux lookout
# Processing Record 37 of Set 7 | hualmay
# Processing Record 38 of Set 7 | tahta
# Processing Record 39 of Set 7 | vagur
# Processing Record 40 of Set 7 | pimentel
# Processing Record 41 of Set 7 | mackenzie
# Processing Record 42 of Set 7 | muskegon
# Processing Record 43 of Set 7 | luena
# Processing Record 44 of Set 7 | rocha
# Processing Record 45 of Set 7 | riyadh
# Processing Record 46 of Set 7 | port-cartier
# Processing Record 47 of Set 7 | contai
# Processing Record 48 of Set 7 | luau
# Processing Record 49 of Set 7 | toyooka
# Processing Record 50 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 1 of Set 8 | florianopolis
# Processing Record 2 of Set 8 | egvekinot
# Processing Record 3 of Set 8 | punto fijo
# Processing Record 4 of Set 8 | boralday
# Processing Record 5 of Set 8 | phalaborwa
# Processing Record 6 of Set 8 | makakilo city
# Processing Record 7 of Set 8 | dehloran
# Processing Record 8 of Set 8 | kidal
# Processing Record 9 of Set 8 | gollere
# City not found. Skipping...
# Processing Record 10 of Set 8 | coquimbo
# Processing Record 11 of Set 8 | sal rei
# Processing Record 12 of Set 8 | verkhnevilyuysk
# Processing Record 13 of Set 8 | codrington
# Processing Record 14 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 8 | lucea
# Processing Record 16 of Set 8 | cherskiy
# Processing Record 17 of Set 8 | bereznik
# Processing Record 18 of Set 8 | barstow
# Processing Record 19 of Set 8 | mount isa
# Processing Record 20 of Set 8 | beringovskiy
# Processing Record 21 of Set 8 | grootfontein
# Processing Record 22 of Set 8 | bend
# Processing Record 23 of Set 8 | alvaraes
# Processing Record 24 of Set 8 | oxapampa
# Processing Record 25 of Set 8 | tambo
# Processing Record 26 of Set 8 | narathiwat
# Processing Record 27 of Set 8 | pacific grove
# Processing Record 28 of Set 8 | mae sai
# Processing Record 29 of Set 8 | ust-nera
# Processing Record 30 of Set 8 | bambanglipuro
# Processing Record 31 of Set 8 | tsiroanomandidy
# Processing Record 32 of Set 8 | kampong chhnang
# Processing Record 33 of Set 8 | chunoyar
# Processing Record 34 of Set 8 | sao filipe
# Processing Record 35 of Set 8 | aqtobe
# Processing Record 36 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 37 of Set 8 | manzhouli
# Processing Record 38 of Set 8 | chebenki
# Processing Record 39 of Set 8 | qasigiannguit
# Processing Record 40 of Set 8 | margate
# Processing Record 41 of Set 8 | takoradi
# Processing Record 42 of Set 8 | kavieng
# Processing Record 43 of Set 8 | cochabamba
# Processing Record 44 of Set 8 | hamilton
# Processing Record 45 of Set 8 | longyearbyen
# Processing Record 46 of Set 8 | la palma
# Processing Record 47 of Set 8 | mandalgovi
# Processing Record 48 of Set 8 | kande
# Processing Record 49 of Set 8 | hongjiang
# Processing Record 50 of Set 8 | talaya
# Processing Record 1 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 9 | pisco
# Processing Record 3 of Set 9 | maraba
# Processing Record 4 of Set 9 | sur
# Processing Record 5 of Set 9 | naze
# Processing Record 6 of Set 9 | nacozari
# Processing Record 7 of Set 9 | comodoro rivadavia
# Processing Record 8 of Set 9 | duxbury
# Processing Record 9 of Set 9 | amguri
# Processing Record 10 of Set 9 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 9 | kenora
# Processing Record 12 of Set 9 | upata
# Processing Record 13 of Set 9 | san quintin
# Processing Record 14 of Set 9 | poum
# Processing Record 15 of Set 9 | campbell river
# Processing Record 16 of Set 9 | faanui
# Processing Record 17 of Set 9 | dergachi
# Processing Record 18 of Set 9 | leshukonskoye
# Processing Record 19 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 9 | dabwali
# Processing Record 21 of Set 9 | maragogi
# Processing Record 22 of Set 9 | pontes e lacerda
# Processing Record 23 of Set 9 | kungurtug
# Processing Record 24 of Set 9 | gewane
# Processing Record 25 of Set 9 | luganville
# Processing Record 26 of Set 9 | san jeronimo
# Processing Record 27 of Set 9 | holly hill
# Processing Record 28 of Set 9 | bogande
# Processing Record 29 of Set 9 | ippy
# Processing Record 30 of Set 9 | kristiinankaupunki
# Processing Record 31 of Set 9 | bagdarin
# Processing Record 32 of Set 9 | manokwari
# Processing Record 33 of Set 9 | port hedland
# Processing Record 34 of Set 9 | doume
# Processing Record 35 of Set 9 | atocha
# Processing Record 36 of Set 9 | novobiryusinskiy
# Processing Record 37 of Set 9 | tumwater
# Processing Record 38 of Set 9 | kaeo
# Processing Record 39 of Set 9 | kaka
# Processing Record 40 of Set 9 | mardin
# Processing Record 41 of Set 9 | ampanihy
# Processing Record 42 of Set 9 | vilyuysk
# Processing Record 43 of Set 9 | korla
# Processing Record 44 of Set 9 | torrington
# Processing Record 45 of Set 9 | sayalgudi
# City not found. Skipping...
# Processing Record 46 of Set 9 | kargopol
# Processing Record 47 of Set 9 | cedar city
# Processing Record 48 of Set 9 | kuala krai
# City not found. Skipping...
# Processing Record 49 of Set 9 | kudahuvadhoo
# Processing Record 50 of Set 9 | port hardy
# Processing Record 1 of Set 10 | daru
# Processing Record 2 of Set 10 | aborlan
# Processing Record 3 of Set 10 | la ronge
# Processing Record 4 of Set 10 | talnakh
# Processing Record 5 of Set 10 | jasper
# Processing Record 6 of Set 10 | cajamarca
# Processing Record 7 of Set 10 | buriti bravo
# Processing Record 8 of Set 10 | marawi
# Processing Record 9 of Set 10 | kutum
# Processing Record 10 of Set 10 | bambous virieux
# Processing Record 11 of Set 10 | ningxiang
# Processing Record 12 of Set 10 | udachnyy
# Processing Record 13 of Set 10 | matara
# Processing Record 14 of Set 10 | duz
# City not found. Skipping...
# Processing Record 15 of Set 10 | saldanha
# Processing Record 16 of Set 10 | tinglev
# Processing Record 17 of Set 10 | taber
# Processing Record 18 of Set 10 | tadine
# Processing Record 19 of Set 10 | san policarpo
# Processing Record 20 of Set 10 | atagay
# Processing Record 21 of Set 10 | port blair
# Processing Record 22 of Set 10 | sibolga
# Processing Record 23 of Set 10 | bonavista
# Processing Record 24 of Set 10 | laguna
# Processing Record 25 of Set 10 | port moresby
# Processing Record 26 of Set 10 | churapcha
# Processing Record 27 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 28 of Set 10 | cockburn town
# Processing Record 29 of Set 10 | beloha
# Processing Record 30 of Set 10 | la rochelle
# Processing Record 31 of Set 10 | corinto
# Processing Record 32 of Set 10 | morant bay
# Processing Record 33 of Set 10 | salinas
# Processing Record 34 of Set 10 | big rapids
# Processing Record 35 of Set 10 | antalya
# Processing Record 36 of Set 10 | labuhan
# Processing Record 37 of Set 10 | gomel
# Processing Record 38 of Set 10 | roznava
# Processing Record 39 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 10 | yumen
# Processing Record 41 of Set 10 | marsaxlokk
# Processing Record 42 of Set 10 | xinzhou
# Processing Record 43 of Set 10 | roald
# Processing Record 44 of Set 10 | mirnyy
# Processing Record 45 of Set 10 | marzuq
# Processing Record 46 of Set 10 | corsicana
# Processing Record 47 of Set 10 | shu
# Processing Record 48 of Set 10 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 49 of Set 10 | bani walid
# Processing Record 50 of Set 10 | eureka
# Processing Record 1 of Set 11 | saint-denis
# Processing Record 2 of Set 11 | emerald
# Processing Record 3 of Set 11 | marovoay
# Processing Record 4 of Set 11 | azimur
# City not found. Skipping...
# Processing Record 5 of Set 11 | east hemet
# Processing Record 6 of Set 11 | jumla
# Processing Record 7 of Set 11 | cap malheureux
# Processing Record 8 of Set 11 | port-gentil
# Processing Record 9 of Set 11 | vila do maio
# Processing Record 10 of Set 11 | benguela
# Processing Record 11 of Set 11 | tezu
# Processing Record 12 of Set 11 | turukhansk
# Processing Record 13 of Set 11 | mareeba
# Processing Record 14 of Set 11 | qafsah
# City not found. Skipping...
# Processing Record 15 of Set 11 | sainte-marie
# Processing Record 16 of Set 11 | abha
# Processing Record 17 of Set 11 | banda aceh
# Processing Record 18 of Set 11 | antofagasta
# Processing Record 19 of Set 11 | onguday
# Processing Record 20 of Set 11 | batagay
# Processing Record 21 of Set 11 | mendi
# Processing Record 22 of Set 11 | vao
# Processing Record 23 of Set 11 | carutapera
# Processing Record 24 of Set 11 | bubaque
# Processing Record 25 of Set 11 | lodja
# Processing Record 26 of Set 11 | college
# Processing Record 27 of Set 11 | conway
# Processing Record 28 of Set 11 | quatre cocos
# Processing Record 29 of Set 11 | aljezur
# Processing Record 30 of Set 11 | skibbereen
# Processing Record 31 of Set 11 | penzance
# Processing Record 32 of Set 11 | nanortalik
# Processing Record 33 of Set 11 | keti bandar
# Processing Record 34 of Set 11 | lumphat
# Processing Record 35 of Set 11 | westport
# Processing Record 36 of Set 11 | panjab
# Processing Record 37 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 38 of Set 11 | ambon
# Processing Record 39 of Set 11 | yar-sale
# Processing Record 40 of Set 11 | urumqi
# Processing Record 41 of Set 11 | lososina
# Processing Record 42 of Set 11 | orahovac
# Processing Record 43 of Set 11 | tuy hoa
# Processing Record 44 of Set 11 | mill valley
# Processing Record 45 of Set 11 | ndioum
# Processing Record 46 of Set 11 | vestmannaeyjar
# Processing Record 47 of Set 11 | ust-kut
# Processing Record 48 of Set 11 | bratslav
# Processing Record 49 of Set 11 | la paz
# Processing Record 50 of Set 11 | kambileyevskoye
# Processing Record 1 of Set 12 | oldenburg
# Processing Record 2 of Set 12 | turkistan
# Processing Record 3 of Set 12 | zonguldak
# Processing Record 4 of Set 12 | pattao
# Processing Record 5 of Set 12 | vaitape
# Processing Record 6 of Set 12 | praia da vitoria
# Processing Record 7 of Set 12 | palmer
# Processing Record 8 of Set 12 | minot
# Processing Record 9 of Set 12 | bilma
# Processing Record 10 of Set 12 | kruisfontein
# Processing Record 11 of Set 12 | te anau
# Processing Record 12 of Set 12 | fort-shevchenko
# Processing Record 13 of Set 12 | sabalgarh
# Processing Record 14 of Set 12 | milkovo
# Processing Record 15 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 16 of Set 12 | angoche
# Processing Record 17 of Set 12 | faya
# Processing Record 18 of Set 12 | cayce
# Processing Record 19 of Set 12 | nobeoka
# Processing Record 20 of Set 12 | banganapalle
# Processing Record 21 of Set 12 | kaset sombun
# Processing Record 22 of Set 12 | kenai
# Processing Record 23 of Set 12 | labuan
# Processing Record 24 of Set 12 | staryy nadym
# Processing Record 25 of Set 12 | yulara
# Processing Record 26 of Set 12 | mangrol
# Processing Record 27 of Set 12 | beckley
# Processing Record 28 of Set 12 | barcelos
# Processing Record 29 of Set 12 | kantilo
# Processing Record 30 of Set 12 | moose factory
# Processing Record 31 of Set 12 | gotsu
# Processing Record 32 of Set 12 | whitley bay
# Processing Record 33 of Set 12 | hirado
# Processing Record 34 of Set 12 | pacifica
# Processing Record 35 of Set 12 | taloqan
# Processing Record 36 of Set 12 | skjervoy
# Processing Record 37 of Set 12 | flinders
# Processing Record 38 of Set 12 | asau
# Processing Record 39 of Set 12 | talara
# Processing Record 40 of Set 12 | pizarro
# Processing Record 41 of Set 12 | pitimbu
# Processing Record 42 of Set 12 | itaqui
# Processing Record 43 of Set 12 | tari
# Processing Record 44 of Set 12 | buariki
# City not found. Skipping...
# Processing Record 45 of Set 12 | poopo
# Processing Record 46 of Set 12 | kalabo
# Processing Record 47 of Set 12 | guanare
# Processing Record 48 of Set 12 | oyama
# Processing Record 49 of Set 12 | chicama
# Processing Record 50 of Set 12 | xiaoweizhai
# Processing Record 1 of Set 13 | ahipara
# Processing Record 2 of Set 13 | villazon
# Processing Record 3 of Set 13 | mackay
# Processing Record 4 of Set 13 | meinung
# City not found. Skipping...
# Processing Record 5 of Set 13 | borama
# City not found. Skipping...
# Processing Record 6 of Set 13 | ciudad bolivar
# Processing Record 7 of Set 13 | cozumel
# Processing Record 8 of Set 13 | ahuimanu
# Processing Record 9 of Set 13 | pangai
# Processing Record 10 of Set 13 | hambantota
# Processing Record 11 of Set 13 | boyuibe
# Processing Record 12 of Set 13 | vrangel
# Processing Record 13 of Set 13 | ordynskoye
# Processing Record 14 of Set 13 | gouyave
# Processing Record 15 of Set 13 | cherdyn
# Processing Record 16 of Set 13 | domanivka
# Processing Record 17 of Set 13 | inyonga
# Processing Record 18 of Set 13 | huancabamba
# Processing Record 19 of Set 13 | ewa beach
# Processing Record 20 of Set 13 | at-bashi
# Processing Record 21 of Set 13 | ormara
# Processing Record 22 of Set 13 | namatanai
# Processing Record 23 of Set 13 | garowe
# Processing Record 24 of Set 13 | itacoatiara
# Processing Record 25 of Set 13 | lima
# Processing Record 26 of Set 13 | ulladulla
# Processing Record 27 of Set 13 | kandrian
# Processing Record 28 of Set 13 | abu kamal
# Processing Record 29 of Set 13 | gizo
# Processing Record 30 of Set 13 | north branch
# Processing Record 31 of Set 13 | kendari
# Processing Record 32 of Set 13 | buchanan
# Processing Record 33 of Set 13 | makokou
# Processing Record 34 of Set 13 | pundaguitan
# Processing Record 35 of Set 13 | camacha
# Processing Record 36 of Set 13 | kindersley
# Processing Record 37 of Set 13 | alyangula
# Processing Record 38 of Set 13 | kununurra
# Processing Record 39 of Set 13 | andevoranto
# City not found. Skipping...
# Processing Record 40 of Set 13 | cessnock
# Processing Record 41 of Set 13 | bolshoy uluy
# City not found. Skipping...
# Processing Record 42 of Set 13 | bolshaya vishera
# City not found. Skipping...
# Processing Record 43 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 44 of Set 13 | hay river
# Processing Record 45 of Set 13 | sacramento
# Processing Record 46 of Set 13 | primero de enero
# Processing Record 47 of Set 13 | kabinda
# Processing Record 48 of Set 13 | auki
# Processing Record 49 of Set 13 | maldonado
# Processing Record 50 of Set 13 | chingirlau
# Processing Record 1 of Set 14 | jalu
# Processing Record 2 of Set 14 | deltona
# Processing Record 3 of Set 14 | guarda
# Processing Record 4 of Set 14 | khandbari
# Processing Record 5 of Set 14 | dunedin
# Processing Record 6 of Set 14 | zolotinka
# City not found. Skipping...
# Processing Record 7 of Set 14 | ribeira brava
# Processing Record 8 of Set 14 | aplahoue
# Processing Record 9 of Set 14 | krasnoye
# Processing Record 10 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 11 of Set 14 | saint-pierre
# Processing Record 12 of Set 14 | tura
# Processing Record 13 of Set 14 | mweka
# Processing Record 14 of Set 14 | lewistown
# Processing Record 15 of Set 14 | canoinhas
# Processing Record 16 of Set 14 | roma
# Processing Record 17 of Set 14 | toppenish
# Processing Record 18 of Set 14 | ureki
# Processing Record 19 of Set 14 | lithgow
# Processing Record 20 of Set 14 | battle creek
# Processing Record 21 of Set 14 | orebro
# Processing Record 22 of Set 14 | xochihuehuetlan
# Processing Record 23 of Set 14 | kralendijk
# Processing Record 24 of Set 14 | spornoye
# Processing Record 25 of Set 14 | aripuana
# Processing Record 26 of Set 14 | tromso
# Processing Record 27 of Set 14 | balikpapan
# Processing Record 28 of Set 14 | niamey
# Processing Record 29 of Set 14 | saquena
# Processing Record 30 of Set 14 | guiyang
# Processing Record 31 of Set 14 | mbigou
# Processing Record 32 of Set 14 | rawson
# Processing Record 33 of Set 14 | orcopampa
# Processing Record 34 of Set 14 | yurty
# Processing Record 35 of Set 14 | goderich
# Processing Record 36 of Set 14 | aswan
# Processing Record 37 of Set 14 | haibowan
# City not found. Skipping...
# Processing Record 38 of Set 14 | digapahandi
# Processing Record 39 of Set 14 | indianola
# Processing Record 40 of Set 14 | helena
# Processing Record 41 of Set 14 | baiyin
# Processing Record 42 of Set 14 | aloleng
# Processing Record 43 of Set 14 | valdez
# Processing Record 44 of Set 14 | shingu
# Processing Record 45 of Set 14 | najran
# Processing Record 46 of Set 14 | terre-de-bas
# Processing Record 47 of Set 14 | valparaiso
# Processing Record 48 of Set 14 | lappeenranta
# Processing Record 49 of Set 14 | pasni
# Processing Record 50 of Set 14 | marsa matruh
# Processing Record 1 of Set 15 | pedernales
# Processing Record 2 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 15 | huilong
# Processing Record 4 of Set 15 | tommot
# Processing Record 5 of Set 15 | dukat
# Processing Record 6 of Set 15 | londoko
# Processing Record 7 of Set 15 | kangaatsiaq
# Processing Record 8 of Set 15 | shenjiamen
# Processing Record 9 of Set 15 | yaan
# Processing Record 10 of Set 15 | fort saint john
# City not found. Skipping...
# Processing Record 11 of Set 15 | bilibino
# Processing Record 12 of Set 15 | tacoronte
# Processing Record 13 of Set 15 | rio branco
# Processing Record 14 of Set 15 | mezen
# Processing Record 15 of Set 15 | shimoda
# Processing Record 16 of Set 15 | lae
# Processing Record 17 of Set 15 | bathsheba
# Processing Record 18 of Set 15 | djibo
# Processing Record 19 of Set 15 | lazo
# Processing Record 20 of Set 15 | kalmunai
# Processing Record 21 of Set 15 | kodar
# Processing Record 22 of Set 15 | nizhneangarsk
# Processing Record 23 of Set 15 | bowen
# Processing Record 24 of Set 15 | antalaha
# Processing Record 25 of Set 15 | tandil
# Processing Record 26 of Set 15 | tawang
# Processing Record 27 of Set 15 | ngunguru
# Processing Record 28 of Set 15 | drayton valley
# Processing Record 29 of Set 15 | basco
# Processing Record 30 of Set 15 | jijiga
# Processing Record 31 of Set 15 | ostrovnoy
# Processing Record 32 of Set 15 | inuvik
# Processing Record 33 of Set 15 | buon me thuot
# City not found. Skipping...
# Processing Record 34 of Set 15 | taunggyi
# Processing Record 35 of Set 15 | gurskoye
# City not found. Skipping...
# Processing Record 36 of Set 15 | gallup
# Processing Record 37 of Set 15 | dunda
# Processing Record 38 of Set 15 | maniitsoq
# Processing Record 39 of Set 15 | nelson bay
# Processing Record 40 of Set 15 | gull lake
# Processing Record 41 of Set 15 | mujiayingzi
# Processing Record 42 of Set 15 | yasugi
# Processing Record 43 of Set 15 | sol-iletsk
# Processing Record 44 of Set 15 | lalomanu
# City not found. Skipping...
# Processing Record 45 of Set 15 | carauari
# Processing Record 46 of Set 15 | ingleside
# Processing Record 47 of Set 15 | puerto cabezas
# Processing Record 48 of Set 15 | monterey
# Processing Record 49 of Set 15 | wanning
# Processing Record 50 of Set 15 | cacu
# Processing Record 1 of Set 16 | okha
# Processing Record 2 of Set 16 | rawannawi
# City not found. Skipping...
# Processing Record 3 of Set 16 | monticello
# Processing Record 4 of Set 16 | damghan
# Processing Record 5 of Set 16 | myitkyina
# Processing Record 6 of Set 16 | bol
# Processing Record 7 of Set 16 | mocambique
# City not found. Skipping...
# Processing Record 8 of Set 16 | taltal
# Processing Record 9 of Set 16 | sigli
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        Albany  42.60  -73.97     48.00        77         100        3.00
# 1  Punta Arenas -53.15  -70.92     39.20        72          20       20.80
# 2       Waitati -45.75  170.57     51.01        80          18        5.99
# 3         Bluff -46.60  168.33     48.99        80           0        5.99
# 4       Qaanaaq  77.48  -69.36      8.08        78          31        9.51
#
#   Country Current Description
# 0      US     overcast clouds
# 1      CL          few clouds
# 2      NZ          few clouds
# 3      NZ           clear sky
# 4      GL    scattered clouds

# %%
# Reorder the columns.
new_column_order = ["City", "Country","Lat", "Lng", "Max Temp","Humidity", "Cloudiness", "Wind Speed", "Current Description"]

city_data_df=city_data_df[new_column_order]
city_data_df.head()
# Out:
#            City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0        Albany      US  42.60  -73.97     48.00        77         100
# 1  Punta Arenas      CL -53.15  -70.92     39.20        72          20
# 2       Waitati      NZ -45.75  170.57     51.01        80          18
# 3         Bluff      NZ -46.60  168.33     48.99        80           0
# 4       Qaanaaq      GL  77.48  -69.36      8.08        78          31
#
#    Wind Speed Current Description
# 0        3.00     overcast clouds
# 1       20.80          few clouds
# 2        5.99          few clouds
# 3        5.99           clear sky
# 4        9.51    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
